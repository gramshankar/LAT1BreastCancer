# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from scipy import stats

# %%
data = pd.read_csv("Log2FC Mann Whitney Data - Premeno.csv", usecols = [i for i in range(1,22,2)])
Ki67 = data["Pre Ki-67"].drop([1,8,9,10,12,16,17,18,23]).dropna()
Basophil = data["Pre Basophil"].dropna()
Eosinophil = data["Pre Eosinophil"].dropna()
Neutrophil = data["Pre Neutrophil"].dropna()
Monocyte = data["Pre Monocyte"].dropna()
WBC = data["Pre WBC"].dropna()
Lymphocyte = data["Pre Lymphocyte"].dropna()

# %%
stats.ttest_ind(Ki67,Basophil)
# Out:
# Ttest_indResult(statistic=-0.31516695622552904, pvalue=0.754971806827349)

# %%
mannwhitneyu(Ki67,Eosinophil)
# Out:
# MannwhitneyuResult(statistic=109.0, pvalue=0.9009714934164412)

# %%
mannwhitneyu(Ki67,Neutrophil)
# Out:
# MannwhitneyuResult(statistic=76.0, pvalue=0.13533864384381597)

# %%
stats.ttest_ind(Ki67,Monocyte)
# Out:
# Ttest_indResult(statistic=-0.5538792027560256, pvalue=0.5840581990012625)

# %%
stats.ttest_ind(Ki67,WBC)
# Out:
# Ttest_indResult(statistic=-1.510797960045059, pvalue=0.14204430616681823)

# %%
mannwhitneyu(Ki67,Lymphocyte)
# Out:
# MannwhitneyuResult(statistic=84.0, pvalue=0.24543248360349268)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fdeaf349-1416-49ba-bea6-de0285ba4c56' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

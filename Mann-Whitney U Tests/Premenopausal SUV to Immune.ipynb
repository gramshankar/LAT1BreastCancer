# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# %%
data = pd.read_csv("Log2FC Mann Whitney Data - Premeno.csv", usecols = [i for i in range(1,22,2)])
SUVMean = data["Pre SUV Mean"].drop([1,8,9,10,12,16,17,18,19,23,25])
SUVPeak = data["Pre SUV Peak"].drop([1,8,9,10,12,16,17,18,19,23,25])
SUVMax = data["Pre SUV Max"].drop([1,8,9,10,12,16,17,18,19,23,25])
Basophil = data["Pre Basophil"].dropna()
Eosinophil = data["Pre Eosinophil"].dropna()
Neutrophil = data["Pre Neutrophil"].dropna()
Monocyte = data["Pre Monocyte"].dropna()
WBC = data["Pre WBC"].dropna()
Lymphocyte = data["Pre Lymphocyte"].dropna()

# %%
mannwhitneyu(SUVMean,Basophil)
# Out:
# MannwhitneyuResult(statistic=89.0, pvalue=0.3387931123615968)

# %%
mannwhitneyu(SUVMean,Eosinophil)
# Out:
# MannwhitneyuResult(statistic=125.0, pvalue=0.6186695570822622)

# %%
mannwhitneyu(SUVMean,Neutrophil)
# Out:
# MannwhitneyuResult(statistic=82.0, pvalue=0.21332278254094483)

# %%
mannwhitneyu(SUVMean,Monocyte)
# Out:
# MannwhitneyuResult(statistic=80.0, pvalue=0.18436124604380766)

# %%
mannwhitneyu(SUVMean,WBC)
# Out:
# MannwhitneyuResult(statistic=106.0, pvalue=0.8034411566561627)

# %%
mannwhitneyu(SUVMean,Lymphocyte)
# Out:
# MannwhitneyuResult(statistic=74.0, pvalue=0.11494702343887914)

# %%
mannwhitneyu(SUVPeak,Basophil)
# Out:
# MannwhitneyuResult(statistic=89.0, pvalue=0.3387931123615968)

# %%
mannwhitneyu(SUVPeak,Eosinophil)
# Out:
# MannwhitneyuResult(statistic=119.0, pvalue=0.8034625743147712)

# %%
mannwhitneyu(SUVPeak,Neutrophil)
# Out:
# MannwhitneyuResult(statistic=88.0, pvalue=0.3194521288966182)

# %%
mannwhitneyu(SUVPeak,Monocyte)
# Out:
# MannwhitneyuResult(statistic=83.0, pvalue=0.22897717637243786)

# %%
mannwhitneyu(SUVPeak,WBC)
# Out:
# MannwhitneyuResult(statistic=93.0, pvalue=0.43059671018389833)

# %%
mannwhitneyu(SUVPeak,Lymphocyte)
# Out:
# MannwhitneyuResult(statistic=77.0, pvalue=0.14653111378242054)

# %%
mannwhitneyu(SUVMax,Basophil)
# Out:
# MannwhitneyuResult(statistic=88.0, pvalue=0.3182105715085366)

# %%
mannwhitneyu(SUVMax,Eosinophil)
# Out:
# MannwhitneyuResult(statistic=119.0, pvalue=0.8034625743147712)

# %%
mannwhitneyu(SUVMax,Neutrophil)
# Out:
# MannwhitneyuResult(statistic=93.0, pvalue=0.43059671018389833)

# %%
mannwhitneyu(SUVMax,Monocyte)
# Out:
# MannwhitneyuResult(statistic=89.0, pvalue=0.34003216856941376)

# %%
mannwhitneyu(SUVMax,WBC)
# Out:
# MannwhitneyuResult(statistic=95.0, pvalue=0.4806822967560067)

# %%
mannwhitneyu(SUVMax,Lymphocyte)
# Out:
# MannwhitneyuResult(statistic=79.0, pvalue=0.17102162039971303)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fdeaf349-1416-49ba-bea6-de0285ba4c56' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
ft = pd.read_csv("FT.csv")
FirstVisit = ft.loc[[11,48,49,58,64,70,82,91,106,115,118,121,137,140,146,161,170,176,182,191,200,230,236,239,251,257,260], :].set_index("cn")
display(FirstVisit.head(10))
# Out:
#     fte2  fte3  fte4  fte5  fte6    fte7  fte8  fte10  fte13  fte14  ...  \
# cn                                                                   ...
# 5      2  2010     1     1   2.0  2010.0   1.0    2.0    1.0    1.0  ...
# 18     3  2010     1     1   2.0  2010.0   1.0    1.0    1.0    2.0  ...
# 19     3  2010     1     1   2.0  2010.0   1.0    1.0    1.0    6.0  ...
# 22     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    4.0  ...
# 24     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    4.0  ...
# 26     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    4.0  ...
# 30     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 33     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0   88.0  ...
# 38     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 41     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
#
#      fte90  fte91   fte92  fte96  FTe3d  FTe7d  FTe29d  FTe90d  FTe92d  FTe96d
# cn
# ...

# %%
weight = FirstVisit["fte30"]

# %%
height = FirstVisit["fte32"]

# %%
bmi = weight/(height/100)**2

# %%
ph = pd.read_csv("PH.csv")
values = ph.loc[[4,16,17,20,22,24,28,31,36,39,40,41,46,47,49,54,57,59,61,64,66,77,79,80,84,85,86], :].set_index("cn")
display(values.head(10))
# Out:
#     phe2  phe3  phe4  phe5    phe6  phe9  phe10  phe11  phe12  phe14  ...  \
# cn                                                                    ...
# 5      1  2011     1     1  2010.0   NaN    2.0  208.0  232.0    NaN  ...
# 18     1  2012     1     1  2010.0   NaN    6.0  118.0  405.0    NaN  ...
# 19     1  2012     1     1  2010.0   NaN    2.0   22.0   84.0    NaN  ...
# 22     1  2013     1     1  2010.0   NaN    0.0    5.0  109.0    NaN  ...
# 24     1  2011     1     1  2010.0   NaN    6.0  307.0  421.0    NaN  ...
# 26     1  2013     1     1     NaN   NaN    2.0   64.0  495.0    NaN  ...
# 30     1  2011     1     1  2011.0   NaN    5.0  281.0  425.0    NaN  ...
# 33     1  2013     1     1  2011.0   NaN    0.0    6.0  160.0    NaN  ...
# 38     1  2012     1     1  2011.0   NaN    0.0   34.0  133.0    NaN  ...
# 41     1  2012     1     1  2011.0   NaN    1.0   33.0  330.0    NaN  ...
#
#     phe62  phe63  phe64  phe65   phe66  phe70  PHe3d  PHe6d  PHe66d  PHe70d
# cn
# ...

# %%
ki67 = values["phe61"]

# %%
pearsonr(bmi,ki67)
# Out:
# PearsonRResult(statistic=0.08015500250292401, pvalue=0.6910503831183035)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3bb7ba91-669a-481d-bbe4-d71a44ec24fc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

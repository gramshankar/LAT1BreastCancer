# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
data = pd.read_csv('All SUV Values - Included Postmenopausal SUV Max.csv', skiprows=[2,14,19,26])
data = data.set_index("ID")

# %%
ph = pd.read_csv("PH.csv")
values = ph.loc[[4,17,20,22,24,28,31,36,39,40,41,46,47,49,57,59,61,64,66,77,79,80,86], :].set_index("cn")

# %%
he = pd.read_csv("HE.csv")
Immune = he.loc[[4,18,21,23,25,29,32,37,40,41,42,48,49,51,59,61,63,66,69,79,81,82,89], :].set_index("cn")

# %%
basophil = Immune["hee124"]
eosinophil = Immune["hee115"]
neutrophil = Immune["hee133"]
monocyte = Immune["hee106"]
WBC = Immune["hee25"]
lymphocyte = Immune["hee97"]
data["basophil"] = basophil
data["eosinophil"] = eosinophil
data["neutrophil"] = neutrophil
data["monocyte"] = monocyte
data["WBC"] = WBC
data["lymphocyte"] = lymphocyte

# %%
ki67 = values["phe61"]

# %%
data["ki67"] = ki67

# %%
data.head()
# Out:
#     SUV Max Scan 1  SUV Max Scan 2 SUV Max Scan 3  SUV Max Scan 4  \
# ID
# 5   14.95  (14.95)  13.09  (13.09)   14.0  (14.0)  14.74  (14.74)
# 18    6.13  (6.13)    7.17  (7.17)   6.73  (6.73)    5.69  (5.69)
# 19    3.82  (3.82)    3.77  (3.77)   3.03  (3.03)    3.21  (3.21)
# 22    2.22  (2.22)    2.31  (2.31)   2.13  (2.13)    2.27  (2.27)
# 24    7.72  (7.72)    6.93  (6.93)   6.87  (6.87)    7.18  (7.18)
#
#     SUV Max Scan 5  basophil  eosinophil  neutrophil  monocyte   WBC  \
# ID
# 5   14.75  (14.75)       0.8         2.5        58.2       5.9  7.30
# 18    5.34  (5.34)       NaN         NaN         NaN       NaN   NaN
# 19    3.51  (3.51)       0.0         3.0        46.0      10.0  3.45
# 22    2.03  (2.03)       0.4         1.6        63.5      10.2  9.80
# 24    7.54  (7.54)       1.0         2.0        59.0       7.0  7.20
#
#     lymphocyte   ki67
# ID
# 5         32.6  844.0
# 18         NaN    NaN
# 19        41.0  220.0
# 22        24.0   40.0
# 24        31.0  751.0

# %%
Ki67 = ki67.tolist()

# %%
basophilA = basophil.tolist()
eosinophilA = eosinophil.tolist()
neutrophilA = neutrophil.tolist()
monocyteA = monocyte.tolist()
WBCA = WBC.tolist()
lymphocyteA = lymphocyte.tolist()

# %%
pearsonr(Ki67,basophilA)
# Out:
# PearsonRResult(statistic=-0.06131066866253086, pvalue=0.7810894391916334)

# %%
pearsonr(Ki67,eosinophilA)
# Out:
# PearsonRResult(statistic=-0.07394354013694485, pvalue=0.7373955762994931)

# %%
pearsonr(Ki67,neutrophilA)
# Out:
# PearsonRResult(statistic=-0.003835825481177622, pvalue=0.9861413766972212)

# %%
pearsonr(Ki67,monocyteA)
# Out:
# PearsonRResult(statistic=-0.07823638754517206, pvalue=0.7227176494531478)

# %%
pearsonr(Ki67,WBCA)
# Out:
# PearsonRResult(statistic=0.06062207382638011, pvalue=0.7834909323431045)

# %%
pearsonr(Ki67,lymphocyteA)
# Out:
# PearsonRResult(statistic=-0.06687208391805485, pvalue=0.7617664451851907)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=580dc3bf-7301-47c1-9bea-3cf330f3bc69' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

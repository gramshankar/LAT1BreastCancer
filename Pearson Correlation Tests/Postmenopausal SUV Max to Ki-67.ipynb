# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
data = pd.read_csv('All SUV Values - Included Postmenopausal SUV Max.csv', skiprows=[2,14,19,26])

# %%
data = data.set_index("ID")

# %%
ph = pd.read_csv("PH.csv")
values = ph.loc[[4,16,17,20,22,24,28,31,36,39,40,41,46,47,49,54,57,59,61,64,66,67,77,79,80,84,85,86], :].set_index("cn")
display(ph.head(90))
display(values.head(90))
# Out:
#     cn  phe2  phe3  phe4  phe5    phe6  phe9  phe10  phe11  phe12  ...  phe62  \
# 0    1     1  2011     1     1  2009.0   NaN    2.0  149.0  490.0  ...    1.0
# 1    2     1  2011     1     1     NaN   NaN    0.0   49.0  154.0  ...    1.0
# 2    3     1  2011     1     1  2010.0   NaN    2.0  182.0  302.0  ...    1.0
# 3    4     1  2011     1     1  2010.0   NaN    3.0   32.0  325.0  ...    1.0
# 4    5     1  2011     1     1  2010.0   NaN    2.0  208.0  232.0  ...    1.0
# ..  ..   ...   ...   ...   ...     ...   ...    ...    ...    ...  ...    ...
# 82  85     1  2012     1     1  2012.0   NaN    2.0   41.0  310.0  ...    1.0
# 83  86     1  2013     1     1  2012.0   NaN    5.0  186.0  348.0  ...    1.0
# 84  87     1  2013     1     1  2012.0   NaN    0.0   33.0  375.0  ...    1.0
# 85  89     1  2012     1     1  2012.0   NaN    0.0   28.0  335.0  ...    1.0
# 86  90     1  2012     1     1  2012.0   NaN    6.0  235.0  365.0  ...    1.0
#
#     phe63  phe64  phe65   phe66  phe70  PHe3d  PHe6d  PHe66d  PHe70d
# 0     NaN   17.0    3.0     NaN   2011    675  -21.0     NaN     687
# 1     NaN   26.0    3.0  2012.0   2012    693    NaN   734.0     734
# 2     NaN   52.0    3.0     NaN   2011    542  -33.0     NaN     554
# 3     NaN   12.0    0.0     NaN   2012    591  -22.0     NaN     635
# 4     NaN   84.0    3.0     NaN   2011    505  -27.0     NaN     518
# ..    ...    ...    ...     ...    ...    ...    ...     ...     ...
# 82    2.0   15.0    3.0     NaN   2012     41  -30.0     NaN      50
# 83    NaN   60.0    3.0     NaN   2012    211  -49.0     NaN       1
# 84    NaN   16.0    3.0     NaN   2012    231  -29.0     NaN     133
# 85    NaN    9.0    3.0     NaN   2012     62  -23.0     NaN      76
# 86    NaN   62.0    3.0     NaN   2012     59  -42.0     NaN      72
#
# [87 rows x 60 columns]
#     phe2  phe3  phe4  phe5    phe6  phe9  phe10  phe11  phe12  phe14  ...  \
# cn                                                                    ...
# 5      1  2011     1     1  2010.0   NaN    2.0  208.0  232.0    NaN  ...
# 18     1  2012     1     1  2010.0   NaN    6.0  118.0  405.0    NaN  ...
# 19     1  2012     1     1  2010.0   NaN    2.0   22.0   84.0    NaN  ...
# 22     1  2013     1     1  2010.0   NaN    0.0    5.0  109.0    NaN  ...
# 24     1  2011     1     1  2010.0   NaN    6.0  307.0  421.0    NaN  ...
# 26     1  2013     1     1     NaN   NaN    2.0   64.0  495.0    NaN  ...
# 30     1  2011     1     1  2011.0   NaN    5.0  281.0  425.0    NaN  ...
# 33     1  2013     1     1  2011.0   NaN    0.0    6.0  160.0    NaN  ...
# 38     1  2012     1     1  2011.0   NaN    0.0   34.0  133.0    NaN  ...
# 41     1  2012     1     1  2011.0   NaN    1.0   33.0  330.0    NaN  ...
# 42     1  2011     1     1  2011.0   NaN    3.0  220.0  370.0    NaN  ...
# 43     1  2012     1     1  2011.0   NaN    3.0  146.0  797.0    NaN  ...
# 49     1  2012     1     1  2011.0   NaN    1.0   13.0  255.0    NaN  ...
# 50     1  2012     1     1  2011.0   NaN    0.0   30.0   93.0    NaN  ...
# 52     1  2012     1     1  2011.0   NaN    1.0   94.0  195.0    NaN  ...
# 57     1  2012     1     1  2011.0   NaN    8.0  286.0  398.0    NaN  ...
# 60     1  2013     1     1  2011.0   NaN    5.0  124.0  445.0    NaN  ...
# 62     1  2013     1     1  2011.0   NaN    2.0  153.0  245.0    NaN  ...
# 64     1  2012     1     1  2011.0   NaN    1.0   93.0  388.0    NaN  ...
# 67     1  2012     1     1  2011.0   NaN    1.0  135.0  194.0    NaN  ...
# 70     1  2012     1     1  2011.0   NaN    0.0   11.0  134.0    NaN  ...
# 71     1  2012     1     1  2011.0   NaN    0.0   74.0  179.0    NaN  ...
# 80     1  2012     1     1  2012.0   NaN    8.0  246.0  259.0    NaN  ...
# 82     1  2012     1     1  2012.0   NaN    3.0  210.0  378.0    NaN  ...
# 83     1  2013     1     1  2012.0   NaN    5.0  185.0  698.0    NaN  ...
# 87     1  2013     1     1  2012.0   NaN    0.0   33.0  375.0    NaN  ...
# 89     1  2012     1     1  2012.0   NaN    0.0   28.0  335.0    NaN  ...
# 90     1  2012     1     1  2012.0   NaN    6.0  235.0  365.0    NaN  ...
#
#     phe62  phe63  phe64  phe65   phe66  phe70  PHe3d  PHe6d  PHe66d  PHe70d
# cn
# 5     1.0    NaN   84.0    3.0     NaN   2011    505  -27.0     NaN     518
# 18    1.0    NaN   30.0    3.0     NaN   2012    778  -12.0     NaN     786
# 19    1.0    NaN   22.0    3.0  2012.0   2012    765  -21.0   765.0     783
# 22    1.0    NaN    4.0    3.0     NaN   2011    941  -13.0     NaN     307
# 24    1.0    NaN   75.0    3.0     NaN   2011    154  -14.0     NaN     154
# 26    1.0    NaN   15.0    3.0     NaN   2013    903    NaN     NaN     904
# 30    1.0    NaN   32.0    1.0     NaN   2011    290  -22.0     NaN     295
# 33    1.0    NaN    9.0    3.0     NaN   2013    763  -21.0     NaN     793
# 38    1.0    2.0   33.0    3.0     NaN   2012    344  -50.0     NaN     357
# 41    1.0    NaN   11.0    3.0     NaN   2012    455  -14.0     NaN     464
# 42    1.0    NaN   68.0    3.0     NaN   2011    125  -27.0     NaN     134
# 43    1.0    2.0   15.0    3.0     NaN   2013    579  -27.0     NaN     632
# 49    1.0    2.0    2.0    1.0     NaN   2012    407  -34.0     NaN     495
# 50    1.0    NaN   24.0    3.0     NaN   2012    402  -34.0     NaN     490
# 52    1.0    NaN   33.0    3.0  2012.0   2011    377  -30.0   377.0       6
# 57    1.0    2.0   61.0    3.0     NaN   2012    127  -14.0     NaN     148
# 60    1.0    NaN   30.0    3.0     NaN   2013    745   -2.0     NaN     747
# 62    1.0    NaN   33.0    3.0     NaN   2013    714 -108.0     NaN     716
# 64    1.0    2.0   26.0    3.0     NaN   2012     71  -19.0     NaN      38
# 67    1.0    NaN   62.0    3.0     NaN   2011    153  -27.0     NaN       2
# 70    1.0    2.0    8.0    1.0     NaN   2012     40  -42.0     NaN      40
# 71    1.0    NaN   33.0    3.0  2012.0   2012     67  -51.0    67.0     103
# 80    1.0    2.0   88.0    3.0     NaN   2012     50  -49.0     NaN      57
# 82    1.0    NaN   46.0    3.0     NaN   2012     42  -14.0     NaN       0
# 83    1.0    NaN   25.0    3.0     NaN   2013    296  -42.0     NaN     326
# 87    1.0    NaN   16.0    3.0     NaN   2012    231  -29.0     NaN     133
# 89    1.0    NaN    9.0    3.0     NaN   2012     62  -23.0     NaN      76
# 90    1.0    NaN   62.0    3.0     NaN   2012     59  -42.0     NaN      72
#
# [28 rows x 59 columns]

# %%
ki67 = values["phe61"]
ki67
# Out:
# cn
# 5     844.0
# 18    296.0
# 19    220.0
# 22     40.0
# 24    751.0
# 26    154.0
# 30    317.0
# 33     88.0
# 38    326.0
# 41    113.0
# 42    697.0
# 43    152.0
# 49     24.0
# 50    244.0
# 52    329.0
# 57    607.0
# 60    297.0
# 62    332.0
# 64    264.0
# 67    624.0
# 70     81.0
# 71    329.0
# 80    883.0
# 82    457.0
# 83    247.0
# 87    157.0
# 89     89.0
# 90    623.0
# Name: phe61, dtype: float64

# %%
data["ki67"] = ki67

# %%
data.head()
# Out:
#     SUV Max Scan 1  SUV Max Scan 2 SUV Max Scan 3  SUV Max Scan 4  \
# ID
# 5   14.95  (14.95)  13.09  (13.09)   14.0  (14.0)  14.74  (14.74)
# 18    6.13  (6.13)    7.17  (7.17)   6.73  (6.73)    5.69  (5.69)
# 19    3.82  (3.82)    3.77  (3.77)   3.03  (3.03)    3.21  (3.21)
# 22    2.22  (2.22)    2.31  (2.31)   2.13  (2.13)    2.27  (2.27)
# 24    7.72  (7.72)    6.93  (6.93)   6.87  (6.87)    7.18  (7.18)
#
#     SUV Max Scan 5   ki67
# ID
# 5   14.75  (14.75)  844.0
# 18    5.34  (5.34)  296.0
# 19    3.51  (3.51)  220.0
# 22    2.03  (2.03)   40.0
# 24    7.54  (7.54)  751.0

# %%
scan1 = data["SUV Max Scan 1"]
scan2 = data["SUV Max Scan 2"]
scan3 = data["SUV Max Scan 3"]
scan4 = data["SUV Max Scan 4"]
scan5 = data["SUV Max Scan 5"]

# %%
Scan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    val = split1.pop(0)
    Scan1.append(float(val))
print(Scan1)
# Out:
# [14.95, 6.13, 3.82, 2.22, 7.72, 7.67, 11.62, 3.24, 4.87, 6.97, 3.18, 4.79, 2.15, 2.72, 4.9, 4.19, 3.96, 6.42, 7.31, 11.94, 7.22, 5.66, 5.64, 7.12, 2.37, 7.1, 6.69, 6.14]

# %%
Scan2 = []
for scan in scan2:
    scana = str(scan)
    split2 = scana.split()
    val = split2.pop(0)
    Scan2.append(float(val))
print(Scan2)
# Out:
# [13.09, 7.17, 3.77, 2.31, 6.93, 7.67, 11.84, 3.59, 4.73, 6.73, 3.56, 4.04, 8.29, 2.74, 4.93, 4.51, 3.87, 6.54, 7.53, 12.62, 6.77, 5.3, 5.23, 7.02, 3.13, 7.0, 6.6, 6.15]

# %%
Scan3 = []
for scan in scan3:
    scana = str(scan)
    split3 = scana.split()
    val = split3.pop(0)
    Scan3.append(float(val))
print(Scan3)
# Out:
# [14.0, 6.73, 3.03, 2.13, 6.87, 9.22, 12.24, 3.48, 4.13, 5.24, 4.93, 3.17, 5.91, 2.3, 4.88, 4.67, 4.26, 5.99, 7.99, 13.18, 6.43, 4.1, 4.36, 6.26, 3.37, 6.26, 6.32, 6.16]

# %%
Scan4 = []
for scan in scan4:
    scana = str(scan)
    split4 = scana.split()
    val = split4.pop(0)
    Scan4.append(float(val))
print(Scan4)
# Out:
# [14.74, 5.69, 3.21, 2.27, 7.18, 7.48, 10.57, 3.07, 3.2, 5.96, 5.08, 2.99, 2.9, 2.17, 4.42, 4.68, 4.31, 5.42, 8.09, 14.23, 6.5, 3.28, 3.83, 3.52, 3.52, 5.15, 6.2, 7.07]

# %%
Scan5 = []
for scan in scan5:
    scana = str(scan)
    split5 = scana.split()
    val = split5.pop(0)
    Scan5.append(float(val))
print(Scan5)
# Out:
# [14.75, 5.34, 3.51, 2.03, 7.54, 5.45, 11.18, 3.12, 4.06, 5.32, 4.74, 2.98, 3.09, 2.47, 4.65, 4.36, 4.37, 5.2, 7.7, 14.82, 6.4, 4.8, 5.37, 6.01, 3.27, 7.19, 6.87, 7.67]

# %%
scan12 = [a + b for a,b in zip(Scan1,Scan2)]
scan34 = [a + b for a,b in zip(Scan3,Scan4)]
scan125 = [a + b for a,b in zip(scan12,Scan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVMaxAverage = [a/5 for a in total]

# %%
Ki67 = ki67.tolist()

# %%
pearsonr(SUVMaxAverage,Ki67)
# Out:
# PearsonRResult(statistic=0.41353182427501173, pvalue=0.02871212632383655)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=580dc3bf-7301-47c1-9bea-3cf330f3bc69' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
data = pd.read_csv('All SUV Values - Included Postmenopausal SUV Mean.csv')

# %%
data = data.set_index("ID")

# %%
ft = pd.read_csv("FT.csv")
FirstVisit = ft.loc[[11,20,48,49,58,64,70,82,91,106,115,118,121,134,137,140,146,161,167,170,176,182,191,197,200,224,230,236,239,251,257,260], :].set_index("cn")
display(ft.head(265))
display(FirstVisit.head(90))
# Out:
#      cn  fte2  fte3  fte4  fte5  fte6    fte7  fte8  fte10  fte13  ...  \
# 0     1     2  2009     1     1   2.0  2009.0   1.0    2.0    1.0  ...
# 1     1     4  2010     1     1   2.0  2010.0   1.0    NaN    1.0  ...
# 2     1     6  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# 3     2     2  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# 4     2     4  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# ..   ..   ...   ...   ...   ...   ...     ...   ...    ...    ...  ...
# 258  89     5  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 259  89     7  2013     1     1   2.0  2013.0   1.0    2.0    1.0  ...
# 260  90     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 261  90     5  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 262  90     7  2013     1     1   2.0  2013.0   1.0    2.0    1.0  ...
#
#       fte90 fte91   fte92  fte96  FTe3d  FTe7d  FTe29d  FTe90d  FTe92d  FTe96d
# 0    2009.0   2.0     NaN   2010      3    3.0     3.0    -1.0     NaN      76
# 1    2009.0   2.0     NaN   2010     64   64.0    64.0    -1.0     NaN      85
# 2    2009.0   2.0  2010.0   2010    100  100.0   100.0    12.0   100.0     121
# 3    2009.0   2.0  2010.0   2010      2    2.0     2.0   -57.0     2.0       8
# 4    2009.0   2.0     NaN   2010     51   51.0    51.0   -77.0     NaN      65
# ..      ...   ...     ...    ...    ...    ...     ...     ...     ...     ...
# 258  2012.0   2.0     NaN   2012     25   13.0    13.0   -10.0     NaN      25
# 259  2012.0   2.0     NaN   2013    203  200.0   200.0   133.0     NaN     203
# 260  2012.0   2.0     NaN   2012      1    1.0     1.0     1.0     NaN      28
# 261  2012.0   2.0     NaN   2012      8    8.0     8.0     8.0     NaN      31
# 262  2013.0   2.0     NaN   2013    188  188.0   188.0   188.0     NaN     213
#
# [263 rows x 77 columns]
#     fte2  fte3  fte4  fte5  fte6    fte7  fte8  fte10  fte13  fte14  ...  \
# cn                                                                   ...
# 5      2  2010     1     1   2.0  2010.0   1.0    2.0    1.0    1.0  ...
# 8      3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    2.0  ...
# 18     3  2010     1     1   2.0  2010.0   1.0    1.0    1.0    2.0  ...
# 19     3  2010     1     1   2.0  2010.0   1.0    1.0    1.0    6.0  ...
# 22     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    4.0  ...
# 24     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    4.0  ...
# 26     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    4.0  ...
# 30     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 33     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0   88.0  ...
# 38     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 41     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
# 42     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    1.0  ...
# 43     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 48     3  2011     1     1   2.0  2011.0   1.0    NaN    1.0    2.0  ...
# 49     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
# 50     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0   88.0  ...
# 52     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
# 57     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 59     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 60     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    4.0  ...
# 62     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    5.0  ...
# 64     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 67     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
# 69     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 70     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    1.0  ...
# 78     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    2.0  ...
# 80     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    1.0  ...
# 82     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    2.0  ...
# 83     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    8.0  ...
# 87     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    2.0  ...
# 89     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    2.0  ...
# 90     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    4.0  ...
#
#      fte90  fte91   fte92  fte96  FTe3d  FTe7d  FTe29d  FTe90d  FTe92d  FTe96d
# cn
# 5   2010.0    2.0     NaN   2010      7    7.0     7.0   -38.0     NaN       7
# 8   2010.0    2.0     NaN   2011      0    0.0     0.0   -93.0     NaN     284
# 18  2009.0    2.0  2010.0   2010      8    8.0     8.0  -386.0     8.0       9
# 19  2009.0    2.0  2010.0   2010      8    8.0     8.0  -394.0     8.0       9
# 22  2010.0    2.0     NaN   2010      9    9.0     9.0   -29.0     NaN      29
# 24  2010.0    2.0     NaN   2011      0    0.0     0.0    36.0     NaN      86
# 26  2010.0    2.0     NaN   2011      0    0.0     0.0   -88.0     NaN       8
# 30  2010.0    2.0     NaN   2011      0    0.0     0.0   -53.0     NaN       3
# 33     NaN    2.0     NaN   2011      0    0.0     0.0     NaN     NaN       8
# 38     NaN    2.0     NaN   2011      0    0.0     0.0     NaN     NaN      27
# 41  2010.0    2.0     NaN   2011      2    2.0     2.0  -216.0     NaN      69
# 42  2011.0    2.0     NaN   2011      0    0.0     0.0   -12.0     NaN       2
# 43  2010.0    2.0     NaN   2011      0    0.0     0.0  -223.0     NaN      62
# 48  2011.0    2.0     NaN   2012      7    7.0     7.0   -98.0     NaN     264
# 49     NaN    2.0     NaN   2011      0    0.0     0.0     NaN     NaN       2
# 50     NaN    2.0     NaN   2011      0    0.0     0.0     NaN     NaN      45
# 52     NaN    2.0     NaN   2011      6    6.0     6.0     NaN     NaN      42
# 57  2011.0    2.0     NaN   2011      3    3.0     3.0   -94.0     NaN       7
# 59  2011.0    2.0     NaN   2011      0    0.0     0.0   -65.0     NaN       7
# 60  2011.0    2.0     NaN   2011      0    0.0     0.0   -93.0     NaN       5
# 62  2011.0    2.0     NaN   2011      7    7.0     7.0  -124.0     NaN      16
# 64  2011.0    2.0     NaN   2011      2    2.0     2.0   -20.0     NaN       7
# 67  2010.0    2.0     NaN   2011      0    0.0     0.0  -368.0     NaN       2
# 69  2011.0    2.0     NaN   2011      0    0.0     0.0   -76.0     NaN       5
# 70  2011.0    2.0     NaN   2012      0    0.0     0.0  -224.0     NaN      38
# 78  2011.0    2.0     NaN   2012      6    6.0     6.0  -113.0     NaN       8
# 80  2012.0    2.0     NaN   2012      0    0.0     0.0   -24.0     NaN      12
# 82  2012.0    2.0     NaN   2012      2    2.0     2.0     1.0     NaN       9
# 83  2012.0    2.0     NaN   2012      0    0.0     0.0   -63.0     NaN      38
# 87  2012.0    2.0     NaN   2012      6    1.0     6.0  -138.0     NaN       6
# 89  2012.0    2.0     NaN   2012     11    4.0     4.0   -10.0     NaN      11
# 90  2012.0    2.0     NaN   2012      1    1.0     1.0     1.0     NaN      28
#
# [32 rows x 76 columns]

# %%
weight = FirstVisit["fte30"]

# %%
height = FirstVisit["fte32"]

# %%
bmi = weight/(height/100)**2

# %%
data["bmi"] = bmi

# %%
data.head()
# Out:
#    SUV Mean Scan 1  SUV Mean Scan 2 SUV Mean Scan 3 SUV Mean Scan 4  \
# ID
# 5        5.07 ± 3.5      5.0 ± 3.13      5.9 ± 3.51      5.61 ± 3.3
# 8        3.3 ± 1.22     2.98 ± 0.93     2.55 ± 0.49      2.3 ± 0.23
# 18      4.14 ± 1.24     4.26 ± 1.45     3.87 ± 1.52     3.53 ± 1.14
# 19      2.81 ± 0.67     2.64 ± 0.58     2.56 ± 0.41     2.66 ± 0.41
# 22      2.12 ± 0.06     2.23 ± 0.12      2.13 ± 0.0      2.27 ± 0.0
#
#    SUV Mean Scan 5        bmi
# ID
# 5      5.48 ± 3.68  28.303850
# 8      2.26 ± 0.18  31.221304
# 18     3.45 ± 1.09  20.173887
# 19     2.66 ± 0.51  26.796875
# 22      2.03 ± 0.0  24.609375

# %%
scan1 = data["SUV Mean Scan 1 "]
scan2 = data["SUV Mean Scan 2"]
scan3 = data["SUV Mean Scan 3"]
scan4 = data["SUV Mean Scan 4"]
scan5 = data["SUV Mean Scan 5"]

# %%
upperScan1 = []
lowerScan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    upperScan1.append(float(split1[0]) + float(split1[2]))
    lowerScan1.append(float(split1[0]) - float(split1[2]))

# %%
upperScan2 = []
lowerScan2 = []
for scan in scan2:
    scana2 = str(scan)
    split2 = scana.split()
    upperScan2.append(float(split2[0]) + float(split2[2]))
    lowerScan2.append(float(split2[0]) - float(split2[2]))

# %%
upperScan3 = []
lowerScan3 = []
for scan in scan3:
    scana3 = str(scan)
    split3 = scan.split()
    upperScan3.append(float(split3[0]) + float(split3[2]))
    lowerScan3.append(float(split3[0]) - float(split3[2]))

# %%
upperScan4 = []
lowerScan4 = []
for scan in scan4:
    scana4 = str(scan)
    split4 = scan.split()
    upperScan4.append(float(split4[0]) + float(split4[2]))
    lowerScan4.append(float(split4[0]) - float(split4[2]))

# %%
upperScan5 = []
lowerScan5 = []
for scan in scan5:
    scana5 = str(scan)
    split5 = scan.split()
    upperScan5.append(float(split5[0]) + float(split5[2]))
    lowerScan5.append(float(split5[0]) - float(split5[2]))

# %%
combinedScan1 = [a + b for a,b in zip(upperScan1,lowerScan1)]
combinedScan2 = [a + b for a,b in zip(upperScan2,lowerScan2)]
combinedScan3 = [a + b for a,b in zip(upperScan3,lowerScan3)]
combinedScan4 = [a + b for a,b in zip(upperScan4,lowerScan4)]
combinedScan5 = [a + b for a,b in zip(upperScan5,lowerScan5)]

# %%
scan12 = [a + b for a,b in zip(combinedScan1,combinedScan2)]
scan34 = [a + b for a,b in zip(combinedScan3,combinedScan4)]
scan125 = [a + b for a,b in zip(scan12,combinedScan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVMeanAverage = [a/10 for a in total]

# %%
BMI = bmi.tolist()

# %%
pearsonr(SUVMeanAverage,BMI)
# Out:
# PearsonRResult(statistic=0.3003246428488298, pvalue=0.09489828399659025)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4b6aecec-1cae-461e-93d3-e7693de0ba6e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

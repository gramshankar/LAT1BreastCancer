# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
data = pd.read_csv('All SUV Values - Included Premenopausal SUV Max.csv')
data = data.drop([1,8,9,12,16,19,23,25])

# %%
data = data.set_index("ID")

# %%
he = pd.read_csv("HE.csv")
Immune = he.loc[[0,2,5,6,9,10,19,27,28,33,39,53,65,72,75,76,78,83], :].set_index("cn")

# %%
basophil = Immune["hee124"]
eosinophil = Immune["hee115"]
neutrophil = Immune["hee133"]
monocyte = Immune["hee106"]
WBC = Immune["hee25"]
lymphocyte = Immune["hee97"]

# %%
data["basophil"] = basophil
data["eosinophil"] = eosinophil
data["neutrophil"] = neutrophil
data["monocyte"] = monocyte
data["WBC"] = WBC
data["lymphocyte"] = lymphocyte

# %%
scan1 = data["SUV Max Scan 1"]
scan2 = data["SUV Max Scan 2"]
scan3 = data["SUV Max Scan 3"]
scan4 = data["SUV Max Scan 4"]
scan5 = data["SUV Max Scan 5"]

# %%
Scan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    val = split1.pop(0)
    Scan1.append(float(val))
print(Scan1)
# Out:
# [5.37, 9.62, 3.71, 6.1, 6.66, 6.68, 3.91, 4.58, 10.5, 5.7, 3.33, 2.5, 2.61, 9.23, 5.11, 3.66, 6.08, 8.25]

# %%
Scan2 = []
for scan in scan2:
    scana = str(scan)
    split2 = scana.split()
    val = split2.pop(0)
    Scan2.append(float(val))
print(Scan2)
# Out:
# [5.97, 11.04, 3.66, 6.55, 6.56, 5.84, 3.77, 4.25, 10.52, 4.53, 3.35, 2.65, 2.37, 10.66, 5.07, 3.72, 5.64, 9.04]

# %%
Scan3 = []
for scan in scan3:
    scana = str(scan)
    split3 = scana.split()
    val = split3.pop(0)
    Scan3.append(float(val))
print(Scan3)
# Out:
# [3.12, 14.85, 3.62, 5.53, 6.27, 8.99, 3.88, 3.84, 10.11, 2.71, 3.71, 2.65, 2.42, 11.76, 4.97, 2.68, 4.73, 7.14]

# %%
Scan4 = []
for scan in scan4:
    scana = str(scan)
    split4 = scana.split()
    val = split4.pop(0)
    Scan4.append(float(val))
print(Scan4)
# Out:
# [3.46, 14.39, 3.88, 5.18, 6.21, 10.77, 3.81, 3.44, 9.78, 4.25, 4.06, 2.74, 2.47, 10.89, 4.79, 3.33, 4.13, 6.19]

# %%
Scan5 = []
for scan in scan5:
    scana = str(scan)
    split5 = scana.split()
    val = split5.pop(0)
    Scan5.append(float(val))
print(Scan5)
# Out:
# [2.36, 14.61, 3.55, 5.38, 5.86, 10.67, 3.18, 4.75, 10.12, 2.45, 3.75, 2.77, 2.48, 9.08, 4.12, 2.02, 5.66, 5.28]

# %%
scan12 = [a + b for a,b in zip(Scan1,Scan2)]
scan34 = [a + b for a,b in zip(Scan3,Scan4)]
scan125 = [a + b for a,b in zip(scan12,Scan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVMaxAverage = [a/5 for a in total]

# %%
basophilA = basophil.tolist()
eosinophilA = eosinophil.tolist()
neutrophilA = neutrophil.tolist()
monocyteA = monocyte.tolist()
WBCA = WBC.tolist()
lymphocyteA = lymphocyte.tolist()

# %%
pearsonr(SUVMaxAverage,basophilA)
# Out:
# PearsonRResult(statistic=-0.16268817350960837, pvalue=0.5189307511766066)

# %%
pearsonr(SUVMaxAverage,eosinophilA)
# Out:
# PearsonRResult(statistic=-0.10079274725391368, pvalue=0.6906717882662469)

# %%
pearsonr(SUVMaxAverage,neutrophilA)
# Out:
# PearsonRResult(statistic=-0.16210746612967955, pvalue=0.5204440475307931)

# %%
pearsonr(SUVMaxAverage,monocyteA)
# Out:
# PearsonRResult(statistic=-0.2377819250661899, pvalue=0.34204982865976974)

# %%
pearsonr(SUVMaxAverage,WBCA)
# Out:
# PearsonRResult(statistic=0.20794505093743784, pvalue=0.40766593835821247)

# %%
pearsonr(SUVMaxAverage,lymphocyteA)
# Out:
# PearsonRResult(statistic=-0.15562607653316327, pvalue=0.5374721910976468)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fdeaf349-1416-49ba-bea6-de0285ba4c56' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

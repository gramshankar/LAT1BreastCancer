# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
data = pd.read_csv('All SUV Values - Included Premenopausal SUV Peak.csv')

# %%
data = data.set_index("ID")

# %%
ft = pd.read_csv("FT.csv")
FirstVisit = ft.loc[[0,3,5,14,17,24,27,52,61,73,76,79,85,94,112,152,173,188,209,215,218,221,227,233,242,248], :].set_index("cn")
display(ft.head(265))
display(FirstVisit.head(90))
# Out:
#      cn  fte2  fte3  fte4  fte5  fte6    fte7  fte8  fte10  fte13  ...  \
# 0     1     2  2009     1     1   2.0  2009.0   1.0    2.0    1.0  ...
# 1     1     4  2010     1     1   2.0  2010.0   1.0    NaN    1.0  ...
# 2     1     6  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# 3     2     2  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# 4     2     4  2010     1     1   2.0  2010.0   1.0    2.0    1.0  ...
# ..   ..   ...   ...   ...   ...   ...     ...   ...    ...    ...  ...
# 258  89     5  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 259  89     7  2013     1     1   2.0  2013.0   1.0    2.0    1.0  ...
# 260  90     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 261  90     5  2012     1     1   2.0  2012.0   1.0    2.0    1.0  ...
# 262  90     7  2013     1     1   2.0  2013.0   1.0    2.0    1.0  ...
#
#       fte90 fte91   fte92  fte96  FTe3d  FTe7d  FTe29d  FTe90d  FTe92d  FTe96d
# 0    2009.0   2.0     NaN   2010      3    3.0     3.0    -1.0     NaN      76
# 1    2009.0   2.0     NaN   2010     64   64.0    64.0    -1.0     NaN      85
# 2    2009.0   2.0  2010.0   2010    100  100.0   100.0    12.0   100.0     121
# 3    2009.0   2.0  2010.0   2010      2    2.0     2.0   -57.0     2.0       8
# 4    2009.0   2.0     NaN   2010     51   51.0    51.0   -77.0     NaN      65
# ..      ...   ...     ...    ...    ...    ...     ...     ...     ...     ...
# 258  2012.0   2.0     NaN   2012     25   13.0    13.0   -10.0     NaN      25
# 259  2012.0   2.0     NaN   2013    203  200.0   200.0   133.0     NaN     203
# 260  2012.0   2.0     NaN   2012      1    1.0     1.0     1.0     NaN      28
# 261  2012.0   2.0     NaN   2012      8    8.0     8.0     8.0     NaN      31
# 262  2013.0   2.0     NaN   2013    188  188.0   188.0   188.0     NaN     213
#
# [263 rows x 77 columns]
#     fte2  fte3  fte4  fte5  fte6    fte7  fte8  fte10  fte13  fte14  ...  \
# cn                                                                   ...
# 1      2  2009     1     1   2.0  2009.0   1.0    2.0    1.0    2.0  ...
# 2      2  2010     1     1   2.0  2010.0   1.0    2.0    1.0    6.0  ...
# 3      2  2010     1     1   2.0  2010.0   1.0    2.0    1.0    4.0  ...
# 6      3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    8.0  ...
# 7      3  2010     1     1   2.0  2010.0   1.0    2.0    1.0   99.0  ...
# 10     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    2.0  ...
# 11     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    2.0  ...
# 20     3  2010     1     1   2.0  2010.0   1.0    2.0    1.0    2.0  ...
# 23     3  2011     1     1   2.0  2011.0   1.0    1.0    1.0    2.0  ...
# 27     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 28     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 29     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    4.0  ...
# 31     3  2011     1     1   2.0  2011.0   1.0    1.0    1.0    2.0  ...
# 34     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    9.0  ...
# 40     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    2.0  ...
# 54     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    9.0  ...
# 61     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    8.0  ...
# 66     3  2011     1     1   2.0  2011.0   1.0    2.0    1.0    6.0  ...
# 73     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    6.0  ...
# 75     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    6.0  ...
# 76     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    9.0  ...
# 77     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    2.0  ...
# 79     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    6.0  ...
# 81     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    4.0  ...
# 84     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    8.0  ...
# 86     3  2012     1     1   2.0  2012.0   1.0    2.0    1.0    3.0  ...
#
#      fte90  fte91   fte92  fte96  FTe3d  FTe7d  FTe29d  FTe90d  FTe92d  FTe96d
# cn
# 1   2009.0    2.0     NaN   2010      3    3.0     3.0    -1.0     NaN      76
# 2   2009.0    2.0  2010.0   2010      2    2.0     2.0   -57.0     2.0       8
# 3   2010.0    2.0     NaN   2010      1    1.0     1.0    -1.0     NaN      20
# 6   2010.0    2.0     NaN   2010      0    0.0     0.0   -63.0     NaN       0
# 7      NaN    2.0  2010.0   2010     -4   -4.0    -4.0     NaN    -4.0      81
# 10  2010.0    2.0     NaN   2010      0    0.0     0.0    -5.0     NaN      43
# 11  2010.0    2.0     NaN   2010      1    1.0     1.0   -10.0     NaN      63
# 20  2010.0    2.0     NaN   2011      0    0.0     0.0    23.0     NaN      72
# 23  2009.0    2.0  2011.0   2011     16   16.0    16.0  -463.0    16.0      28
# 27  2011.0    2.0     NaN   2011      1    1.0     1.0    -5.0     NaN      76
# 28  2011.0    2.0     NaN   2011      0    0.0     0.0     0.0     NaN       3
# 29  2011.0    2.0     NaN   2011      0    0.0     0.0     0.0     NaN       0
# 31  2009.0    2.0  2011.0   2011     16   16.0    16.0  -527.0    16.0      20
# 34  2011.0    2.0     NaN   2011      0    0.0     0.0     4.0     NaN      20
# 40     NaN    2.0     NaN   2011      0    0.0     0.0     NaN     NaN       7
# 54  2011.0    2.0     NaN   2011      4    4.0     4.0   -72.0     NaN      11
# 61  2011.0    2.0     NaN   2011      6    1.0     1.0   -33.0     NaN       6
# 66  2011.0    2.0     NaN   2011      5    5.0     5.0     6.0     NaN      11
# 73  2011.0    2.0     NaN   2012      0    0.0     0.0   -20.0     NaN      54
# 75  2011.0    2.0     NaN   2012     14    1.0     1.0  -129.0     NaN      14
# 76  2012.0    2.0     NaN   2012      0    0.0     0.0   -21.0     NaN      15
# 77     NaN    2.0     NaN   2012      4    4.0     4.0     NaN     NaN      34
# 79  2012.0    2.0     NaN   2012      0    0.0     0.0   -29.0     NaN       8
# 81  2012.0    2.0     NaN   2012      3    3.0     3.0   -29.0     NaN       4
# 84     NaN    2.0     NaN   2012      0    0.0     0.0     NaN     NaN       1
# 86  2011.0    2.0     NaN   2012      0    0.0     0.0  -252.0     NaN       0
#
# [26 rows x 76 columns]

# %%
weight = FirstVisit["fte30"]
print(weight)
# Out:
# cn
# 1      87.20
# 2      74.00
# 3      86.80
# 6      66.00
# 7      77.57
# 10     94.00
# 11     65.00
# 20     97.00
# 23     90.00
# 27     69.85
# 28     82.40
# 29     81.50
# 31     70.50
# 34     73.90
# 40     77.10
# 54     71.76
# 61     84.36
# 66     58.50
# 73     77.00
# 75     91.00
# 76     60.30
# 77     63.00
# 79     96.40
# 81    107.00
# 84     84.82
# 86     81.60
# Name: fte30, dtype: float64

# %%
height = FirstVisit["fte32"]
print(height)
# Out:
# cn
# 1     169.00
# 2     162.00
# 3     170.20
# 6     165.00
# 7     167.60
# 10    168.00
# 11    163.00
# 20    157.00
# 23    170.00
# 27    170.18
# 28    170.00
# 29    158.00
# 31    155.00
# 34    157.50
# 40    160.00
# 54    165.10
# 61    160.02
# 66     64.00
# 73    175.00
# 75    160.02
# 76    156.20
# 77    162.60
# 79    165.50
# 81    173.00
# 84    165.10
# 86    175.30
# Name: fte32, dtype: float64

# %%
bmi = weight/(height/100)**2

# %%
bmi
# Out:
# cn
# 1      30.531144
# 2      28.196921
# 3      29.964057
# 6      24.242424
# 7      27.615045
# 10     33.304989
# 11     24.464602
# 20     39.352509
# 23     31.141869
# 27     24.118449
# 28     28.512111
# 29     32.647012
# 31     29.344433
# 34     29.790879
# 40     30.117187
# 54     26.326206
# 61     32.944888
# 66    142.822266
# 73     25.142857
# 75     35.537990
# 76     24.714695
# 77     23.828652
# 79     35.195006
# 81     35.751278
# 84     31.117459
# 86     26.553778
# dtype: float64

# %%
data["bmi"] = bmi

# %%
data.head()
# Out:
#    SUV Peak Scan 1 SUV Peak Scan 2 SUV Peak Scan 3 SUV Peak Scan 4  \
# ID
# 1     3.87  (3.87)    3.99  (3.99)      2.6  (2.6)    2.63  (2.63)
# 2     3.24  (3.24)    3.18  (3.18)    2.59  (2.59)    2.43  (2.43)
# 3     7.55  (7.55)      9.2  (9.2)  11.96  (11.96)    10.7  (10.7)
# 6     3.16  (3.16)    3.29  (3.29)    3.08  (3.08)    3.47  (3.47)
# 7     5.23  (5.23)      5.0  (5.0)    4.41  (4.41)    3.76  (3.76)
#
#    SUV Peak Scan 5        bmi
# ID
# 1     2.18  (2.18)  30.531144
# 2     3.41  (3.41)  28.196921
# 3   11.95  (11.95)  29.964057
# 6     2.62  (2.62)  24.242424
# 7       3.9  (3.9)  27.615045

# %%
scan1 = data["SUV Peak Scan 1"]
scan2 = data["SUV Peak Scan 2"]
scan3 = data["SUV Peak Scan 3"]
scan4 = data["SUV Peak Scan 4"]
scan5 = data["SUV Peak Scan 5"]

# %%
Scan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    val = split1.pop(0)
    Scan1.append(float(val))
print(Scan1)
# Out:
# [3.87, 3.24, 7.55, 3.16, 5.23, 5.47, 4.83, 3.13, 2.76, 3.96, 3.95, 9.37, 3.65, 4.49, 2.8, 2.31, 3.15, 2.35, 8.72, 6.43, 4.69, 3.08, 4.68, 5.07, 6.12, 12.02]

# %%
Scan2 = []
for scan in scan2:
    scana = str(scan)
    split2 = scana.split()
    val = split2.pop(0)
    Scan2.append(float(val))
print(Scan2)
# Out:
# [3.99, 3.18, 9.2, 3.29, 5.0, 5.65, 4.51, 3.14, 2.63, 4.84, 3.46, 9.5, 3.5, 3.7, 2.67, 2.38, 3.19, 2.2, 9.93, 5.68, 4.66, 3.08, 4.48, 4.75, 6.79, 12.12]

# %%
Scan3 = []
for scan in scan3:
    scana = str(scan)
    split3 = scana.split()
    val = split3.pop(0)
    Scan3.append(float(val))
print(Scan3)
# Out:
# [2.6, 2.59, 11.96, 3.08, 4.41, 5.16, 7.71, 3.04, 2.39, 4.97, 3.4, 9.07, 3.07, 2.37, 3.21, 2.4, 2.86, 2.42, 10.65, 6.06, 4.6, 2.45, 3.94, 3.58, 5.57, 12.28]

# %%
Scan4 = []
for scan in scan4:
    scana = str(scan)
    split4 = scana.split()
    val = split4.pop(0)
    Scan4.append(float(val))
print(Scan4)
# Out:
# [2.63, 2.43, 10.7, 3.47, 3.76, 4.95, 9.48, 3.18, 2.08, 3.35, 2.9, 8.4, 2.67, 3.53, 3.56, 2.47, 3.09, 2.36, 9.83, 6.7, 4.34, 2.68, 3.51, 3.17, 5.2, 12.56]

# %%
Scan5 = []
for scan in scan5:
    scana = str(scan)
    split5 = scana.split()
    val = split5.pop(0)
    Scan5.append(float(val))
print(Scan5)
# Out:
# [2.18, 3.41, 11.95, 2.62, 3.9, 4.53, 6.41, 2.79, 2.69, 3.53, 3.88, 8.69, 2.84, 2.27, 3.33, 2.49, 3.22, 2.48, 7.99, 6.9, 3.69, 2.02, 4.45, 3.84, 4.46, 11.71]

# %%
scan12 = [a + b for a,b in zip(Scan1,Scan2)]
scan34 = [a + b for a,b in zip(Scan3,Scan4)]
scan125 = [a + b for a,b in zip(scan12,Scan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVPeakAverage = [a/5 for a in total]

# %%
BMI = bmi.tolist()

# %%
pearsonr(SUVPeakAverage,BMI)
# Out:
# PearsonRResult(statistic=-0.1967370449848595, pvalue=0.3354030316167379)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=eabd138e-f7c3-40f5-b36c-56f1b730c532' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
import pandas as pd
from scipy.stats import shapiro

# %%
data = pd.read_csv('All SUV Values - Included Postmenopausal SUV Max.csv')

# %%
data = data.set_index("ID")

# %%
data.head()
# Out:
#     SUV Max Scan 1  SUV Max Scan 2 SUV Max Scan 3  SUV Max Scan 4  \
# ID
# 5   14.95  (14.95)  13.09  (13.09)   14.0  (14.0)  14.74  (14.74)
# 8     5.88  (5.88)    4.97  (4.97)   3.73  (3.73)    2.79  (2.79)
# 18    6.13  (6.13)    7.17  (7.17)   6.73  (6.73)    5.69  (5.69)
# 19    3.82  (3.82)    3.77  (3.77)   3.03  (3.03)    3.21  (3.21)
# 22    2.22  (2.22)    2.31  (2.31)   2.13  (2.13)    2.27  (2.27)
#
#     SUV Max Scan 5
# ID
# 5   14.75  (14.75)
# 8     2.67  (2.67)
# 18    5.34  (5.34)
# 19    3.51  (3.51)
# 22    2.03  (2.03)

# %%
scan1 = data["SUV Max Scan 1"]
scan2 = data["SUV Max Scan 2"]
scan3 = data["SUV Max Scan 3"]
scan4 = data["SUV Max Scan 4"]
scan5 = data["SUV Max Scan 5"]

# %%
Scan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    val = split1.pop(0)
    Scan1.append(float(val))
print(Scan1)
# Out:
# [14.95, 5.88, 6.13, 3.82, 2.22, 7.72, 7.67, 11.62, 3.24, 4.87, 6.97, 3.18, 4.79, 5.44, 2.15, 2.72, 4.9, 4.19, 8.11, 3.96, 6.42, 7.31, 11.94, 7.22, 5.66, 14.33, 5.64, 7.12, 2.37, 7.1, 6.69, 6.14]

# %%
Scan2 = []
for scan in scan2:
    scana = str(scan)
    split2 = scana.split()
    val = split2.pop(0)
    Scan2.append(float(val))
print(Scan2)
# Out:
# [13.09, 4.97, 7.17, 3.77, 2.31, 6.93, 7.67, 11.84, 3.59, 4.73, 6.73, 3.56, 4.04, 5.09, 8.29, 2.74, 4.93, 4.51, 8.16, 3.87, 6.54, 7.53, 12.62, 6.77, 5.3, 14.88, 5.23, 7.02, 3.13, 7.0, 6.6, 6.15]

# %%
Scan3 = []
for scan in scan3:
    scana = str(scan)
    split3 = scana.split()
    val = split3.pop(0)
    Scan3.append(float(val))
print(Scan3)
# Out:
# [14.0, 3.73, 6.73, 3.03, 2.13, 6.87, 9.22, 12.24, 3.48, 4.13, 5.24, 4.93, 3.17, 4.84, 5.91, 2.3, 4.88, 4.67, 7.28, 4.26, 5.99, 7.99, 13.18, 6.43, 4.1, 14.75, 4.36, 6.26, 3.37, 6.26, 6.32, 6.16]

# %%
Scan4 = []
for scan in scan4:
    scana = str(scan)
    split4 = scana.split()
    val = split4.pop(0)
    Scan4.append(float(val))
print(Scan4)
# Out:
# [14.74, 2.79, 5.69, 3.21, 2.27, 7.18, 7.48, 10.57, 3.07, 3.2, 5.96, 5.08, 2.99, 4.09, 2.9, 2.17, 4.42, 4.68, 5.58, 4.31, 5.42, 8.09, 14.23, 6.5, 3.28, 14.72, 3.83, 3.52, 3.52, 5.15, 6.2, 7.07]

# %%
Scan5 = []
for scan in scan5:
    scana = str(scan)
    split5 = scana.split()
    val = split5.pop(0)
    Scan5.append(float(val))
print(Scan5)
# Out:
# [14.75, 2.67, 5.34, 3.51, 2.03, 7.54, 5.45, 11.18, 3.12, 4.06, 5.32, 4.74, 2.98, 5.34, 3.09, 2.47, 4.65, 4.36, 6.88, 4.37, 5.2, 7.7, 14.82, 6.4, 4.8, 10.49, 5.37, 6.01, 3.27, 7.19, 6.87, 7.67]

# %%
scan12 = [a + b for a,b in zip(Scan1,Scan2)]
scan34 = [a + b for a,b in zip(Scan3,Scan4)]
scan125 = [a + b for a,b in zip(scan12,Scan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVMaxAverage = [a/5 for a in total]

# %%
shapiro(SUVMaxAverage)
# Out:
# ShapiroResult(statistic=0.8344928026199341, pvalue=0.00019488530233502388)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=614a4d97-888c-4dae-b318-a643026e8049' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

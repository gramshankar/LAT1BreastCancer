# %%
import pandas as pd
from scipy.stats import shapiro

# %%
he = pd.read_csv("HE.csv")
Immune = he.loc[[0,2,5,6,9,10,19,27,28,33,39,53,65,72,75,76,78,83], :].set_index("cn")

# %%
basophil = Immune["hee124"]
eosinophil = Immune["hee115"]
neutrophil = Immune["hee133"]
monocyte = Immune["hee106"]
WBC = Immune["hee25"]
lymphocyte = Immune["hee97"]

# %%
basophilA = basophil.tolist()
eosinophilA = eosinophil.tolist()
neutrophilA = neutrophil.tolist()
monocyteA = monocyte.tolist()
WBCA = WBC.tolist()
lymphocyteA = lymphocyte.tolist()

# %%
shapiro(basophilA)
# Out:
# ShapiroResult(statistic=0.914449155330658, pvalue=0.103094682097435)

# %%
shapiro(eosinophilA)
# Out:
# ShapiroResult(statistic=0.8349559903144836, pvalue=0.004949017893522978)

# %%
shapiro(neutrophilA)
# Out:
# ShapiroResult(statistic=0.8205533027648926, pvalue=0.003008645959198475)

# %%
shapiro(monocyteA)
# Out:
# ShapiroResult(statistic=0.90524822473526, pvalue=0.07097382098436356)

# %%
shapiro(WBCA)
# Out:
# ShapiroResult(statistic=0.9008040428161621, pvalue=0.059341587126255035)

# %%
shapiro(lymphocyteA)
# Out:
# ShapiroResult(statistic=0.8438869118690491, pvalue=0.006793159991502762)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c7ebffe6-47cc-4c78-8dd2-9d95e2560fdb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

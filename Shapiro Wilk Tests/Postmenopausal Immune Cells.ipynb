# %%
import pandas as pd
from scipy.stats import shapiro

# %%
he = pd.read_csv("HE.csv")
Immune = he.loc[[4,7,18,21,23,25,29,32,37,40,41,42,47,48,49,51,59,61,63,66,69,77,79,81,82,89], :].set_index("cn")

# %%
basophil = Immune["hee124"]
eosinophil = Immune["hee115"]
neutrophil = Immune["hee133"]
monocyte = Immune["hee106"]
WBC = Immune["hee25"]
lymphocyte = Immune["hee97"]

# %%
basophilA = basophil.tolist()
eosinophilA = eosinophil.tolist()
neutrophilA = neutrophil.tolist()
monocyteA = monocyte.tolist()
WBCA = WBC.tolist()
lymphocyteA = lymphocyte.tolist()

# %%
shapiro(basophilA)
# Out:
# ShapiroResult(statistic=0.2371058464050293, pvalue=1.3320428093877013e-10)

# %%
shapiro(eosinophilA)
# Out:
# ShapiroResult(statistic=0.21140146255493164, pvalue=8.565749498590236e-11)

# %%
shapiro(neutrophilA)
# Out:
# ShapiroResult(statistic=0.7537171840667725, pvalue=3.165242014802061e-05)

# %%
shapiro(monocyteA)
# Out:
# ShapiroResult(statistic=0.21513837575912476, pvalue=9.12790398821528e-11)

# %%
shapiro(WBCA)
# Out:
# ShapiroResult(statistic=0.9050471186637878, pvalue=0.020331479609012604)

# %%
shapiro(lymphocyteA)
# Out:
# ShapiroResult(statistic=0.21191120147705078, pvalue=8.64023852464868e-11)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=83688d7d-1734-4708-b379-d62eae976bc4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

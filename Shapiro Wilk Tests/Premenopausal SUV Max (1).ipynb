# %%
import pandas as pd
from scipy.stats import shapiro

# %%
data = pd.read_csv('All SUV Values - Included Premenopausal SUV Max.csv')

# %%
data = data.set_index("ID")

# %%
data.head()
# Out:
#    SUV Max Scan 1  SUV Max Scan 2  SUV Max Scan 3  SUV Max Scan 4  \
# ID
# 1    5.37  (5.37)    5.97  (5.97)    3.12  (3.12)    3.46  (3.46)
# 2    4.21  (4.21)    3.52  (3.52)      3.1  (3.1)    2.98  (2.98)
# 3     9.62 (9.62)  11.04  (11.04)  14.85  (14.85)  14.39  (14.39)
# 6    3.71  (3.71)    3.66  (3.66)    3.62  (3.62)    3.88  (3.88)
# 7      6.1  (6.1)    6.55  (6.55)    5.53  (5.53)    5.18  (5.18)
#
#     SUV Max Scan 5
# ID
# 1     2.36  (2.36)
# 2     4.93  (4.93)
# 3   14.61  (14.61)
# 6     3.55  (3.55)
# 7     5.38  (5.38)

# %%
scan1 = data["SUV Max Scan 1"]
scan2 = data["SUV Max Scan 2"]
scan3 = data["SUV Max Scan 3"]
scan4 = data["SUV Max Scan 4"]
scan5 = data["SUV Max Scan 5"]

# %%
Scan1 = []
for scan in scan1:
    scana = str(scan)
    split1 = scana.split()
    val = split1.pop(0)
    Scan1.append(float(val))
print(Scan1)
# Out:
# [5.37, 4.21, 9.62, 3.71, 6.1, 6.66, 6.68, 3.91, 3.87, 5.21, 4.58, 10.5, 4.56, 5.7, 3.33, 2.5, 3.24, 2.61, 9.23, 6.88, 5.11, 3.66, 6.08, 6.9, 8.25, 12.72]

# %%
Scan2 = []
for scan in scan2:
    scana = str(scan)
    split2 = scana.split()
    val = split2.pop(0)
    Scan2.append(float(val))
print(Scan2)
# Out:
# [5.97, 3.52, 11.04, 3.66, 6.55, 6.56, 5.84, 3.77, 3.12, 6.12, 4.25, 10.52, 4.09, 4.53, 3.35, 2.65, 3.29, 2.37, 10.66, 6.39, 5.07, 3.72, 5.64, 7.01, 9.04, 13.36]

# %%
Scan3 = []
for scan in scan3:
    scana = str(scan)
    split3 = scana.split()
    val = split3.pop(0)
    Scan3.append(float(val))
print(Scan3)
# Out:
# [3.12, 3.1, 14.85, 3.62, 5.53, 6.27, 8.99, 3.88, 2.56, 6.99, 3.84, 10.11, 3.73, 2.71, 3.71, 2.65, 3.03, 2.42, 11.76, 6.67, 4.97, 2.68, 4.73, 4.5, 7.14, 13.59]

# %%
Scan4 = []
for scan in scan4:
    scana = str(scan)
    split4 = scana.split()
    val = split4.pop(0)
    Scan4.append(float(val))
print(Scan4)
# Out:
# [3.46, 2.98, 14.39, 3.88, 5.18, 6.21, 10.77, 3.81, 2.08, 4.62, 3.44, 9.78, 3.15, 4.25, 4.06, 2.74, 3.25, 2.47, 10.89, 7.0, 4.79, 3.33, 4.13, 3.95, 6.19, 13.28]

# %%
Scan5 = []
for scan in scan5:
    scana = str(scan)
    split5 = scana.split()
    val = split5.pop(0)
    Scan5.append(float(val))
print(Scan5)
# Out:
# [2.36, 4.93, 14.61, 3.55, 5.38, 5.86, 10.67, 3.18, 3.46, 4.75, 4.75, 10.12, 3.62, 2.45, 3.75, 2.77, 3.43, 2.48, 9.08, 7.28, 4.12, 2.02, 5.66, 4.57, 5.28, 12.74]

# %%
scan12 = [a + b for a,b in zip(Scan1,Scan2)]
scan34 = [a + b for a,b in zip(Scan3,Scan4)]
scan125 = [a + b for a,b in zip(scan12,Scan5)]
total = [a + b for a,b in zip(scan125,scan34)]

# %%
SUVMaxAverage = [a/5 for a in total]

# %%
shapiro(SUVMaxAverage)
# Out:
# ShapiroResult(statistic=0.8349784016609192, pvalue=0.0007374148117378354)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0c0fdeb8-1379-4e15-a449-fbf2f0c7ed88' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
